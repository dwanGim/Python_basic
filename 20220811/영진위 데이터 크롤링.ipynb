# %% [markdown]
# # api 크롤링
#
# 기존의 크롤링 방식은
#
# 1. 내가 직접 홈페이지에 브라우저를 켜서 접근하거나(selenium)
#
# 혹은
#
# 2. 파이썬 자체적으로 호출을 요청해서(requests)
#
# 데이터를 가지고 오는 방식이었습니다.
#
# 이 방식은 서버에 부하가 많이 갈 뿐더러 나에게 필요없는 데이터까지 한 번에 호출해서 가져오는 문제가 있습니다.
#
# 따라서 서비스 제공자측에서는 서버 부하를 줄이고, 사용자에게 맞춤형을 데이터를 제공하기 위해 api서버를 운영합니다.
#
# api서버는 인가된 데이터만을 개발자에게 넘겨서 서버도 안정적으로 유지하며(횟수 제한이 있는 사이트도 많습니다. 라이엇 데이터는 1초에 5회, 2분에 100회로 제한됩니다.)
#
# 필요없는 동영상자료나 그림자료를 호출하지 않으므로 트래픽을 줄일 수 있습니다.
#
#
#
# api 서버 접근시 보통 urllib.request 를 이용하게 됩니다.

# %%
# 사이트에 자료 요청
import urllib.request 
# json 데이터 핸들링
import json 
# DataFrame 자료형 활용
import pandas as pd 
# json 데이터를 pandas DataFrame으로 변환
#from pandas.io.json import json_normalize

# %% [markdown]
# # 영진위 api신청
#
# http://www.kobis.or.kr/kobisopenapi/homepg/main/main.do
#
# 1. 접속 후 가입 및 로그인
#
# 2. 키발급 탭에서 키 발급하기
#
# 3. 요청 api종류 보고 요청양식 및 데이터 확인하기

# %%
api_key = "89b46798466ecb7f5c0135cb289b0be7" # 발급받은 키만 복붙하세요
request_date = "20220622" # 조회날짜를  xxxxyydd 20220623 형식으로 넣어주세요
url = "http://kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchDailyBoxOfficeList.json?key=%s&targetDt=%s" % (api_key, request_date)
print(url)
# Out:
# http://kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchDailyBoxOfficeList.json?key=89b46798466ecb7f5c0135cb289b0be7&targetDt=20220622

# %% [markdown]
# # json데이터를 팬더스 데이터프레임으로 변환
#
# api 데이터는 보통 json(JavaScript Object Notation) 타입으로 받아집니다.
#
# 쉽게 말하면 자바스크립트 데이터를 전달하기 좋게 설정한 자료형인데
#
# 파이썬의 딕셔너리와 거의 같다고 보시면 됩니다.
#
# 따라서 json 데이터를 팬더스 데이터로 변환한다는 것은 사실상
#
# 딕셔너리 데이터를 팬더스 데이터프레임으로 변환하는것입니다.

# %%
# 위의 url 변수를 이용해 데이터를 요청합니다.
r = urllib.request.urlopen(url)

# 요청 페이지의 결과 데이터를 파이썬 내부 데이터로 바꿉니다.
json_raw = r.read()

# %%
# b'~~~~~~~'로 시작하는 이 데이터는 파이썬에서 byte자료형으로 처리되고
# 데이터프레임으로는 바로 변환이 불가능합니다.
json_raw
# Out:
# b'{"boxOfficeResult":{"boxofficeType":"\xec\x9d\xbc\xeb\xb3\x84 \xeb\xb0\x95\xec\x8a\xa4\xec\x98\xa4\xed\x94\xbc\xec\x8a\xa4","showRange":"20220622~20220622","dailyBoxOfficeList":[{"rnum":"1","rank":"1","rankInten":"0","rankOldAndNew":"NEW","movieCd":"20194376","movieNm":"\xed\x83\x91\xea\xb1\xb4: \xeb\xa7\xa4\xeb\xb2\x84\xeb\xa6\xad","openDt":"2022-06-22","salesAmt":"1976049530","salesShare":"54.3","salesInten":"1976049530","salesChange":"100","salesAcc":"2716938360","audiCnt":"188312","audiInten":"188312","audiChange":"100","audiAcc":"253016","scrnCnt":"1975","showCnt":"9158"},{"rnum":"2","rank":"2","rankInten":"-1","rankOldAndNew":"OLD","movieCd":"20224882","movieNm":"\xeb\xa7\x88\xeb\x85\x80(\xe9\xad\x94\xe5\xa5\xb3) Part2. The Other One","openDt":"2022-06-15","salesAmt":"836476290","salesShare":"23.0","salesInten":"-253649090","salesChange":"-23.3","salesAcc":"18226409650","audiCnt":"82691","audiInten":"-25491","audiChange":"-23.6","audiAcc":"1769461","scrnCnt":"976","showCnt":"3502"},{"rnum":"3","rank":"3","rankInten":"-1","rankOldAndNew":"OLD","movieCd":"20204548","movieNm":"\xeb\xb2\x94\xec\xa3\x84\xeb\x8f\x84\xec\x8b\x9c 2","openDt":"2022-05-18","salesAmt":"577713370","salesShare":"15.9","salesInten":"-158550060","salesChange":"-21.5","salesAcc":"120660923940","audiCnt":"57874","audiInten":"-15988","audiChange":"-21.6","audiAcc":"11671470","scrnCnt":"774","showCnt":"2531"},{"rnum":"4","rank":"4","rankInten":"-1","rankOldAndNew":"OLD","movieCd":"20206257","movieNm":"\xeb\xb8\x8c\xeb\xa1\x9c\xec\xbb\xa4","openDt":"2022-06-08","salesAmt":"96967760","salesShare":"2.7","salesInten":"-120719520","salesChange":"-55.5","salesAcc":"11616358360","audiCnt":"9992","audiInten":"-12366","audiChange":"-55.3","audiAcc":"1160649","scrnCnt":"449","showCnt":"674"},{"rnum":"5","rank":"5","rankInten":"-1","rankOldAndNew":"OLD","movieCd":"20223839","movieNm":"\xeb\xb2\x84\xec\xa6\x88 \xeb\x9d\xbc\xec\x9d\xb4\xed\x8a\xb8\xec\x9d\xb4\xec\x96\xb4","openDt":"2022-06-15","salesAmt":"34719200","salesShare":"1.0","salesInten":"-99957740","salesChange":"-74.2","salesAcc":"2493961690","audiCnt":"3952","audiInten":"-8455","audiChange":"-68.1","audiAcc":"233278","scrnCnt":"287","showCnt":"375"},{"rnum":"6","rank":"6","rankInten":"-1","rankOldAndNew":"OLD","movieCd":"20206061","movieNm":"\xec\xa5\xac\xeb\x9d\xbc\xea\xb8\xb0 \xec\x9b\x94\xeb\x93\x9c: \xeb\x8f\x84\xeb\xaf\xb8\xeb\x8b\x88\xec\x96\xb8","openDt":"2022-06-01","salesAmt":"21223800","salesShare":"0.6","salesInten":"-76011160","salesChange":"-78.2","salesAcc":"28777337910","audiCnt":"2271","audiInten":"-7685","audiChange":"-77.2","audiAcc":"2788530","scrnCnt":"117","showCnt":"141"},{"rnum":"7","rank":"7","rankInten":"0","rankOldAndNew":"NEW","movieCd":"20224757","movieNm":"\xeb\xa3\xb8 \xec\x89\x90\xec\x96\xb4\xeb\xa7\x81","openDt":"2022-06-22","salesAmt":"13283560","salesShare":"0.4","salesInten":"13283560","salesChange":"100","salesAcc":"33442560","audiCnt":"1586","audiInten":"1586","audiChange":"100","audiAcc":"3937","scrnCnt":"122","showCnt":"190"},{"rnum":"8","rank":"8","rankInten":"12","rankOldAndNew":"OLD","movieCd":"20178501","movieNm":"\xeb\x8b\x88 \xeb\xb6\x80\xeb\xaa\xa8 \xec\x96\xbc\xea\xb5\xb4\xec\x9d\xb4 \xeb\xb3\xb4\xea\xb3\xa0 \xec\x8b\xb6\xeb\x8b\xa4","openDt":"2022-04-27","salesAmt":"5090000","salesShare":"0.1","salesInten":"3590000","salesChange":"239.3","salesAcc":"3912819280","audiCnt":"1015","audiInten":"715","audiChange":"238.3","audiAcc":"409303","scrnCnt":"3","showCnt":"4"},{"rnum":"9","rank":"9","rankInten":"5","rankOldAndNew":"OLD","movieCd":"20199500","movieNm":"\xeb\x9c\xa8\xea\xb1\xb0\xec\x9a\xb4 \xed\x94\xbc","openDt":"2022-03-23","salesAmt":"5000000","salesShare":"0.1","salesInten":"2500000","salesChange":"100","salesAcc":"3776252970","audiCnt":"1000","audiInten":"500","audiChange":"100","audiAcc":"396788","scrnCnt":"4","showCnt":"5"},{"rnum":"10","rank":"9","rankInten":"5","rankOldAndNew":"OLD","movieCd":"20212783","movieNm":"\xeb\xa1\x9c\xec\x8a\xa4\xed\x8a\xb ...

# %%
# 바이트자료형임을 확인
type(json_raw)
# Out:
# bytes

# %%
# 따라서 utf-8 형식으로 고쳐줘야 합니다. .decode()를 이용합니다.
# encode => 우리가 쓰는 문자를 컴퓨터가 쓰는 형태로 변환
# decode => 컴퓨터가 쓰는 형태의 문자를 우리가 쓰는 형태로 변환
json_utf8 = json_raw.decode("utf-8")

# %%
# 딕셔너리 구조를 유지하고 있는 문자로 변환됨
type(json_utf8)
# Out:
# str

# %%
json_utf8
# Out:
# '{"boxOfficeResult":{"boxofficeType":"일별 박스오피스","showRange":"20220622~20220622","dailyBoxOfficeList":[{"rnum":"1","rank":"1","rankInten":"0","rankOldAndNew":"NEW","movieCd":"20194376","movieNm":"탑건: 매버릭","openDt":"2022-06-22","salesAmt":"1976049530","salesShare":"54.3","salesInten":"1976049530","salesChange":"100","salesAcc":"2716938360","audiCnt":"188312","audiInten":"188312","audiChange":"100","audiAcc":"253016","scrnCnt":"1975","showCnt":"9158"},{"rnum":"2","rank":"2","rankInten":"-1","rankOldAndNew":"OLD","movieCd":"20224882","movieNm":"마녀(魔女) Part2. The Other One","openDt":"2022-06-15","salesAmt":"836476290","salesShare":"23.0","salesInten":"-253649090","salesChange":"-23.3","salesAcc":"18226409650","audiCnt":"82691","audiInten":"-25491","audiChange":"-23.6","audiAcc":"1769461","scrnCnt":"976","showCnt":"3502"},{"rnum":"3","rank":"3","rankInten":"-1","rankOldAndNew":"OLD","movieCd":"20204548","movieNm":"범죄도시 2","openDt":"2022-05-18","salesAmt":"577713370","salesShare":"15.9","salesInten":"-158550060","salesChange":"-21.5","salesAcc":"120660923940","audiCnt":"57874","audiInten":"-15988","audiChange":"-21.6","audiAcc":"11671470","scrnCnt":"774","showCnt":"2531"},{"rnum":"4","rank":"4","rankInten":"-1","rankOldAndNew":"OLD","movieCd":"20206257","movieNm":"브로커","openDt":"2022-06-08","salesAmt":"96967760","salesShare":"2.7","salesInten":"-120719520","salesChange":"-55.5","salesAcc":"11616358360","audiCnt":"9992","audiInten":"-12366","audiChange":"-55.3","audiAcc":"1160649","scrnCnt":"449","showCnt":"674"},{"rnum":"5","rank":"5","rankInten":"-1","rankOldAndNew":"OLD","movieCd":"20223839","movieNm":"버즈 라이트이어","openDt":"2022-06-15","salesAmt":"34719200","salesShare":"1.0","salesInten":"-99957740","salesChange":"-74.2","salesAcc":"2493961690","audiCnt":"3952","audiInten":"-8455","audiChange":"-68.1","audiAcc":"233278","scrnCnt":"287","showCnt":"375"},{"rnum":"6","rank":"6","rankInten":"-1","rankOldAndNew":"OLD","movieCd":"20206061","movieNm":"쥬라기 월드: 도미니언","openDt":"2022-06-01","salesAmt":"21223800","salesShare":"0.6","salesInten":"-76011160","salesChange":"-78.2","salesAcc":"28777337910","audiCnt":"2271","audiInten":"-7685","audiChange":"-77.2","audiAcc":"2788530","scrnCnt":"117","showCnt":"141"},{"rnum":"7","rank":"7","rankInten":"0","rankOldAndNew":"NEW","movieCd":"20224757","movieNm":"룸 쉐어링","openDt":"2022-06-22","salesAmt":"13283560","salesShare":"0.4","salesInten":"13283560","salesChange":"100","salesAcc":"33442560","audiCnt":"1586","audiInten":"1586","audiChange":"100","audiAcc":"3937","scrnCnt":"122","showCnt":"190"},{"rnum":"8","rank":"8","rankInten":"12","rankOldAndNew":"OLD","movieCd":"20178501","movieNm":"니 부모 얼굴이 보고 싶다","openDt":"2022-04-27","salesAmt":"5090000","salesShare":"0.1","salesInten":"3590000","salesChange":"239.3","salesAcc":"3912819280","audiCnt":"1015","audiInten":"715","audiChange":"238.3","audiAcc":"409303","scrnCnt":"3","showCnt":"4"},{"rnum":"9","rank":"9","rankInten":"5","rankOldAndNew":"OLD","movieCd":"20199500","movieNm":"뜨거운 피","openDt":"2022-03-23","salesAmt":"5000000","salesShare":"0.1","salesInten":"2500000","salesChange":"100","salesAcc":"3776252970","audiCnt":"1000","audiInten":"500","audiChange":"100","audiAcc":"396788","scrnCnt":"4","showCnt":"5"},{"rnum":"10","rank":"9","rankInten":"5","rankOldAndNew":"OLD","movieCd":"20212783","movieNm":"로스트 시티","openDt":"2022-04-20","salesAmt":"5000000","salesShare":"0.1","salesInten":"2500000","salesChange":"100","salesAcc":"1006394850","audiCnt":"1000","audiInten":"500","audiChange":"100","audiAcc":"109848","scrnCnt":"4","showCnt":"5"}]}}'

# %%
# json.loads(딕셔너리 형태의 문자열 자료)
# 딕셔너리 형태로 적힌 문자열 자료를 딕셔너리형으로 변환
json_complete = json.loads(json_utf8)

# %%
# 딕셔너리(json) 변환 완료 확인
type(json_complete)
# Out:
# dict

# %%
# json_normalize(딕셔너리 자료)
# 딕셔너리 자료를 데이터프레임 형태로 변환해줌.
pd.json_normalize(json_complete)
# Out:
#   boxOfficeResult.boxofficeType boxOfficeResult.showRange  \
# 0                      일별 박스오피스         20220622~20220622
#
#                   boxOfficeResult.dailyBoxOfficeList
# 0  [{'rnum': '1', 'rank': '1', 'rankInten': '0', ...

# %%
# boxOfficeResult.dailyBoxOfficeList 컬럼 내부에 딕셔너리가 여럿 묶인 리스트가 보이므로
# boxOfficeResult.dailyBoxOfficeList 컬럼을 타겟으로 데이터프레임화 합니다.
box_result = pd.json_normalize(json_complete['boxOfficeResult']['dailyBoxOfficeList'])

# %%
# json_normalize()는 pd.DataFrame() 으로 대체 가능합니다.
pd.DataFrame(json_complete)
# Out:
#                                                       boxOfficeResult
# boxofficeType                                                일별 박스오피스
# dailyBoxOfficeList  [{'rnum': '1', 'rank': '1', 'rankInten': '0', ...
# showRange                                           20220622~20220622

# %% [markdown]
# API 크롤링으로 서비스 제공시
#
# 사용자가 조회할때마다 매번 API서버에 요청을 넣어서 데이터를 가져오면
#
# 호출횟수를 금방 소모하게 됩니다.
#
# 따라서, 보통 API를 활용한 서비스는 미리 데이터를 DB에 적재해놓고
#
# 사용자가 요청시 내 DB에 있는 데이터를 우선적으로 보여주고, 없으면 외부서버에
#
# 요청해서 내 DB에 INSERT한 다음 다시 내 DB데이터를 사용자에게 보여줍니다.

# %%
url
# Out:
# 'http://kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchDailyBoxOfficeList.json?key=89b46798466ecb7f5c0135cb289b0be7&targetDt=20220622'

# %% [markdown]
# 날짜 데이터는 28일까지인 달(2월), 30일까지인 달, 31일까지인 달 들이 있어서
#
# 단순히 문자열에 1씩 더하거나 날짜처리를 하기도 어렵고
#
# 위의 처리를 다 했다고 해도 4년에 1번 윤달이 있습니다(2월 29일)
#
# 그래서, 날짜는 전적으로 날짜데이터를 이용해 처리해야만 합니다.
#
# 파이썬에서는 datetime을 이용해 처리합니다.(자바는 java.util.Date를 써서 처리)

# %%
import time
import datetime # 파이썬 날짜 자료형

# %%
start_datetime = datetime.datetime(2021, 8, 9) # 년 월 일 순으로 넣어줍니다.
# 형식 바꾸기
target_date = start_datetime.strftime('%Y%m%d') #영진위 형식으로 변경
print(target_date)
# 날짜 하루 올리기
next_datetime = start_datetime - datetime.timedelta(days=1)
next_datetime
# Out:
# 20210809
# datetime.datetime(2021, 8, 8, 0, 0)

# %%
target_dates = ['20220805','20220806','20220807']
# 날짜는 시작날짜와 + 며칠 을 처리할지 결정할 수 있습니다.
# 3일치 데이터를 얻은 다음 to_csv나 to_excel로 저장해주세요.

# 반복문과 append를 이용해서 3일치 데이터를 요청해서 합쳐보세요.
# target_date 컬럼에 조회 날짜를 추가해주세요.
# 빈 데이터프레임을 하나 생성해놓고(pd.DataFrame())
merged_data = pd.DataFrame()
for date in target_dates:
    api_key = "89b46798466ecb7f5c0135cb289b0be7" # 발급받은 키만 복붙하세요
    request_date = date # 조회날짜를  xxxxyydd 20220623 형식으로 넣어주세요
    url = "http://kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchDailyBoxOfficeList.json?key=%s&targetDt=%s" % (api_key, request_date)
    # 위의 url 변수를 이용해 데이터를 요청합니다.
    r = urllib.request.urlopen(url)

    # 요청 페이지의 결과 데이터를 파이썬 내부 데이터로 바꿉니다.
    json_raw = r.read()
    
    json_utf8 = json_raw.decode("utf-8")
    # json.loads(딕셔너리 형태의 문자열 자료)
    # 딕셔너리 형태로 적힌 문자열 자료를 딕셔너리형으로 변환
    json_complete = json.loads(json_utf8)
    box_result = pd.json_normalize(json_complete['boxOfficeResult']['dailyBoxOfficeList'])
    # box_result에 날짜 컬럼 추가해 날짜 정보 넣기
    box_result['date'] = request_date
    merged_data = pd.concat([merged_data, box_result])
merged_data
# Out:
#   rnum rank rankInten rankOldAndNew   movieCd  \
# 0    1    1         1           OLD  20209343
# 1    2    2        -1           OLD  20196410
# 2    3    3         1           OLD  20194376
# 3    4    4        -1           OLD  20205362
# 4    5    5         0           OLD  20225190
# 5    6    6         0           OLD  20209654
# 6    7    7         0           OLD  20208446
# 7    8    8         0           OLD  20226107
# 8    9    9         0           OLD  20225237
# 9   10   10        26           OLD  20224882
# 0    1    1         0           OLD  20209343
# 1    2    2         0           OLD  20196410
# 2    3    3         0           OLD  20194376
# 3    4    4         0           OLD  20205362
# 4    5    5         0           OLD  20225190
# 5    6    6         1           OLD  20208446
# 6    7    7        -1           OLD  20209654
# 7    8    8         0           OLD  20226107
# 8    9    9         0           OLD  20225237
# 9   10   10         0           NEW  20211792
# 0    1    1         0           OLD  20209343
# 1    2    2         0           OLD  20196410
# 2    3    3         0           OLD  20194376
# 3    4    4         0           OLD  20205362
# 4    5    5         0           OLD  20225190
# 5    6    6         1           OLD  20209654
# 6    7    7        -1           OLD  20208446
# 7    8    8         0           OLD  20226107
# 8    9    9         0           OLD  20225237
# 9   10   10         0           OLD  20211792
#
#                            movieNm      openDt    salesAmt salesShare  \
# 0                        한산: 용의 출현  2022-07-27  2565550184       41.6
# 1                             비상선언  2022-08-03  2094794151       34.0
# 2                          탑건: 매버릭  2022-06-22   504483247        8.2
# 3                            미니언즈2  2022-07-20   413915957        6.7
# 4                뽀로로 극장판 드래곤캐슬 대모험  2022-07-28   167553618        2.7
# 5                           헤어질 결심  2022-06-29   142017614        2.3
# 6                          외계+인 1부  2022-07-20   113278760        1.8
# 7  극장판 도라에몽: 진구의 우주소전쟁 리틀스타워즈 2021  2022-08-03    49992320        0.8
# 8                  명탐정 코난: 할로윈의 신부  2022-07-13    27421500        0.4
# 9      마녀(魔女) Part2. The Other One  2022-06-15    12398000        0.2
# 0                        한산: 용의 출현  2022-07-27  4833676390       45.1
# 1                             비상선언  2022-08-03  3450046301       32.2
# 2                          탑건: 매버릭  2022-06-22   813824500        7.6
# 3                            미니언즈2  2022-07-20   675153336        6.3
# 4                뽀로로 극장판 드래곤캐슬 대모험  2022-07-28   262266899        2.4
# 5                          외계+인 1부  2022-07-20   222289537        2.1
# 6                           헤어질 결심  2022-06-29   201851173        1.9
# 7  극장판 도라에몽: 진구의 우주소전쟁 리틀스타워즈 2021  2022-08-03    75556800        0.7
# 8                  명탐정 코난: 할로윈의 신부  2022-07-13    44011900        0.4
# 9                               헌트  2022-08-10    32089200        0.3
# 0                        한산: 용의 출현  2022-07-27  4580762431       47.1
# 1                             비상선언  2022-08-03  2937124308       30.2
# 2                          탑건: 매버릭  2022-06-22   747974164        7.7
# 3                            미니언즈2  2022-07-20   665186085        6.8
# 4                뽀로로 극장판 드래곤캐슬 대모험  2022-07-28   264177800        2.7
# 5                           헤어질 결심  2022-06-29   169174033        1.7
# 6                          외계+인 1부  2022-07-20   123965118        1.3
# 7  극장판 도라에몽: 진구의 우주소전쟁 리틀스타워즈 2021  2022-08-03    77727199        0.8
# 8                  명탐정 코난: 할로윈의 신부  2022-07-13    44635198        0.5
# 9                               헌트  2022-08-10    29793598        0.3
#
#    salesInten salesChange     salesAcc audiCnt audiInten audiChange  audiAcc  \
# 0   530997656        26.1  37567502644  250627     41282       19.7  3692256
# 1    71360791         3.5   7693510482  213574     -8540       -3.8   794756
# 2   148299938        41.6  77905691474   46942     12422         36  7305820
# 3      948579         0.2  17793920900   43092     -1769       -3.9  1837967
# 4    -5960802        -3.4   2909201168   18088     -1181       -6.1   312147
# 5    34703455        32.3  18014179742   13226      3017       29.6  1741846
# 6    22370761        24.6  15283607796   11557      2267       24.4  1466378
# 7    -4086959        -7.6    192969299    5266      -680      -11.4    20859
# 8     3966180        16.9   4509942774    2517       232       10.2   434339
# 9    11939500        2604  28919650670    2433      2378     4323.6  2806159
# 0  2268126206        88.4  42401179034  465415    214788       85.7  4157671
# 1  1355252150        64.7  11143556783  324478    110904       51.9  1119234
# 2   309341253        61.3  78719515974   74351     27409       58.4  7380171
# 3   261237379        63.1  18469074236   68046     24954       57.9  1906013
# 4    94713281        56.5   3171468067   27419      9331       51.6   339566
# 5   109010777        96.2  15505897333   18867      7310       63.3  1485245
# 6    59833559        42.1  18216030915   18001      4775       36.1  1759847
# 7    25564480        51.1    268526099    7655      2389       45.4    28514
# 8    16590400        60.5   4553954674    4109      1592       63.2   438448
# 9    32089200         100    135753200    2543      2543        100    14196
# 0  -252913959        -5.2  46981941465  440812    -24603       -5.3  4598483
# 1  -512921993       -14.9  14080681091  278728    -45750      -14.1  1397962
# 2   -65850336        -8.1  79467490138   68709     -5642       -7.6  7448880
# 3    -9967251        -1.5  19134260321   66774     -1272       -1.9  1972787
# 4     1910901         0.7   3435645867   27591       172        0.6   367157
# 5   -32677140       -16.2  18385204948   15203     -2798      -15.5  1775050
# 6   -98324419       -44.2  15629862451   11690     -7177        -38  1496935
# 7     2170399         2.9    346253298    7903       248        3.2    36417
# 8      623298         1.4   4598589872    4122        13        0.3   442570
# 9    -2295602        -7.2    165546798    2377      -166       -6.5    16573
#
#   scrnCnt showCnt      date
# 0    1530    6343  20220805
# 1    1718    7281  20220805
# 2     605    1238  20220805
# 3     783    1595  20220805
# 4     537     779  20220805
# 5     265     432  20220805
# 6     407     576  20220805
# 7     362     513  20220805
# 8      75      94  20220805
# 9      20      20  20220805
# 0    1637    6816  20220806
# 1    1619    6862  20220806
# 2     631    1310  20220806
# 3     818    1734  20220806
# 4     581     863  20220806
# 5     396     548  20220806
# 6     278     438  20220806
# 7     360     472  20220806
# 8      96     119  20220806
# 9      10      10  20220806
# 0    1638    6769  20220807
# 1    1588    6619  20220807
# 2     632    1304  20220807
# 3     812    1721  20220807
# 4     573     860  20220807
# 5     266     426  20220807
# 6     374     499  20220807
# 7     357     466  20220807
# 8      91     115  20220807
# 9      12      13  20220807

# %%
# 날짜는 시작날짜와 + 며칠 을 처리할지 결정할 수 있습니다.
# 1년치 데이터를 얻은 다음 to_csv나 to_excel로 저장해주세요.
start_datetime = datetime.datetime(2021, 8, 8) # 년 월 일 순으로 넣어줍니다.

# 반복문과 append를 이용해서 1년치 데이터를 요청해서 합쳐보세요.
# target_date 컬럼에 조회 날짜를 추가해주세요.
# 빈 데이터프레임을 하나 생성해놓고(pd.DataFrame())
merged_data = pd.DataFrame()
for idx in range(365):
    # 날짜를 문자로 변경
    target_date = start_datetime.strftime('%Y%m%d')
    
    api_key = "f5eef3421c602c6cb7ea224104795888" # 발급받은 키만 복붙하세요
    request_date = target_date # 조회날짜를  xxxxyydd 20220623 형식으로 넣어주세요
    url = "http://kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchDailyBoxOfficeList.json?key=%s&targetDt=%s" % (api_key, request_date)
    # 위의 url 변수를 이용해 데이터를 요청합니다.
    r = urllib.request.urlopen(url)

    # 요청 페이지의 결과 데이터를 파이썬 내부 데이터로 바꿉니다.
    json_raw = r.read()
    
    json_utf8 = json_raw.decode("utf-8")
    # json.loads(딕셔너리 형태의 문자열 자료)
    # 딕셔너리 형태로 적힌 문자열 자료를 딕셔너리형으로 변환
    json_complete = json.loads(json_utf8)
    box_result = pd.json_normalize(json_complete['boxOfficeResult']['dailyBoxOfficeList'])
    # box_result에 날짜 컬럼 추가해 날짜 정보 넣기
    box_result['date'] = request_date
    merged_data = pd.concat([merged_data, box_result])
    # 해당 날짜 데이터를 가져와 통합한 뒤에는 날짜를 하루 더해주기
    start_datetime = start_datetime + datetime.timedelta(days=1)
    print("%s일차 자료 수집 완료" % idx)
    # 너무 자주 크롤링시 블록먹을 가능성이 있음.
    time.sleep(0.3)
    
merged_data
# Out:
# 0일차 자료 수집 완료
# 1일차 자료 수집 완료
# 2일차 자료 수집 완료
# 3일차 자료 수집 완료
# 4일차 자료 수집 완료
# 5일차 자료 수집 완료
# 6일차 자료 수집 완료
# 7일차 자료 수집 완료
# 8일차 자료 수집 완료
# 9일차 자료 수집 완료
# 10일차 자료 수집 완료
# 11일차 자료 수집 완료
# 12일차 자료 수집 완료
# 13일차 자료 수집 완료
# 14일차 자료 수집 완료
# 15일차 자료 수집 완료
# 16일차 자료 수집 완료
# 17일차 자료 수집 완료
# 18일차 자료 수집 완료
# 19일차 자료 수집 완료
# 20일차 자료 수집 완료
# 21일차 자료 수집 완료
# 22일차 자료 수집 완료
# 23일차 자료 수집 완료
# 24일차 자료 수집 완료
# 25일차 자료 수집 완료
# 26일차 자료 수집 완료
# 27일차 자료 수집 완료
# 28일차 자료 수집 완료
# 29일차 자료 수집 완료
# 30일차 자료 수집 완료
# 31일차 자료 수집 완료
# 32일차 자료 수집 완료
# 33일차 자료 수집 완료
# 34일차 자료 수집 완료
# 35일차 자료 수집 완료
# 36일차 자료 수집 완료
# 37일차 자료 수집 완료
# 38일차 자료 수집 완료
# 39일차 자료 수집 완료
# 40일차 자료 수집 완료
# 41일차 자료 수집 완료
# 42일차 자료 수집 완료
# 43일차 자료 수집 완료
# 44일차 자료 수집 완료
# 45일차 자료 수집 완료
# 46일차 자료 수집 완료
# 47일차 자료 수집 완료
# 48일차 자료 수집 완료
# 49일차 자료 수집 완료
# 50일차 자료 수집 완료
# 51일차 자료 수집 완료
# 52일차 자료 수집 완료
# 53일차 자료 수집 완료
# 54일차 자료 수집 완료
# 55일차 자료 수집 완료
# 56일차 자료 수집 완료
# 57일차 자료 수집 완료
# 58일차 자료 수집 완료
# 59일차 자료 수집 완료
# 60일차 자료 수집 완료
# 61일차 자료 수집 완료
# 62일차 자료 수집 완료
# 63일차 자료 수집 완료
# 64일차 자료 수집 완료
# 65일차 자료 수집 완료
# 66일차 자료 수집 완료
# 67일차 자료 수집 완료
# 68일차 자료 수집 완료
# 69일차 자료 수집 완료
# 70일차 자료 수집 완료
# 71일차 자료 수집 완료
# 72일차 자료 수집 완료
# 73일차 자료 수집 완료
# 74일차 자료 수집 완료
# 75일차 자료 수집 완료
# 76일차 자료 수집 완료
# 77일차 자료 수집 완료
# 78일차 자료 수집 완료
# 79일차 자료 수집 완료
# 80일차 자료 수집 완료
# 81일차 자료 수집 완료
# 82일차 자료 수집 완료
# 83일차 자료 수집 완료
# 84일차 자료 수집 완료
# 85일차 자료 수집 완료
# 86일차 자료 수집 완료
# 87일차 자료 수집 완료
# 88일차 자료 수집 완료
# 89일차 자료 수집 완료
# 90일차 자료 수집 완료
# 91일차 자료 수집 완료
# 92일차 자료 수집 완료
# 93일차 자료 수집 완료
# 94일차 자료 수집 완료
# 95일차 자료 수집 완료
# 96일차 자료 수집 완료
# 97일차 자료 수집 완료
# 98일차 자료 수집 완료
# 99일차 자료 수집 완료
# 100일차 자료 수집 완료
# 101일차 자료 수집 완료
# 102일차 자료 수집 완료
# 103일차 자료 수집 완료
# 104일차 자료 수집 완료
# 105일차 자료 수집 완료
# 106일차 자료 수집 완료
# 107일차 자료 수집 완료
# 108일차 자료 수집 완료
# 109일차 자료 수집 완료
# 110일차 자료 수집 완료
# 111일차 자료 수집 완료
# 112일차 자료 수집 완료
# 113일차 자료 수집 완료
# 114일차 자료 수집 완료
# 115일차 자료 수집 완료
# 116일차 자료 수집 완료
# 117일차 자료 수집 완료
# 118일차 자료 수집 완료
# 119일차 자료 수집 완료
# 120일차 자료 수집 완료
# 121일차 자료 수집 완료
# 122일차 자료 수집 완료
# 123일차 자료 수집 완료
# 124일차 자료 수집 완료
# 125일차 자료 수집 완료
# 126일차 자료 수집 완료
# 127일차 자료 수집 완료
# 128일차 자료 수집 완료
# 129일차 자료 수집 완료
# 130일차 자료 수집 완료
# 131일차 자료 수집 완료
# 132일차 자료 수집 완료
# 133일차 자료 수집 완료
# 134일차 자료 수집 완료
# 135일차 자료 수집 완료
# 136일차 자료 수집 완료
# 137일차 자료 수집 완료
# 138일차 자료 수집 완료
# 139일차 자료 수집 완료
# 140일차 자료 수집 완료
# 141일차 자료 수집 완료
# 142일차 자료 수집 완료
# 143일차 자료 수집 완료
# 144일차 자료 수집 완료
# 145일차 자료 수집 완료
# 146일차 자료 수집 완료
# 147일차 자료 수집 완료
# 148일차 자료 수집 완료
# 149일차 자료 수집 완료
# 150일차 자료 수집 완료
# 151일차 자료 수집 완료
# 152일차 자료 수집 완료
# 153일차 자료 수집 완료
# 154일차 자료 수집 완료
# 155일차 자료 수집 완료
# 156일차 자료 수집 완료
# 157일차 자료 수집 완료
# 158일차 자료 수집 완료
# 159일차 자료 수집 완료
# 160일차 자료 수집 완료
# 161일차 자료 수집 완료
# 162일차 자료 수집 완료
# 163일차 자료 수집 완료
# 164일차 자료 수집 완료
# 165일차 자료 수집 완료
# 166일차 자료 수집 완료
# 167일차 자료 수집 완료
# 168일차 자료 수집 완료
# 169일차 자료 수집 완료
# 170일차 자료 수집 완료
# 171일차 자료 수집 완료
# 172일차 자료 수집 완료
# 173일차 자료 수집 완료
# 174일차 자료 수집 완료
# 175일차 자료 수집 완료
# 176일차 자료 수집 완료
# 177일차 자료 수집 완료
# 178일차 자료 수집 완료
# 179일차 자료 수집 완료
# 180일차 자료 수집 완료
# 181일차 자료 수집 완료
# 182일차 자료 수집 완료
# 183일차 자료 수집 완료
# 184일차 자료 수집 완료
# 185일차 자료 수집 완료
# 186일차 자료 수집 완료
# 187일차 자료 수집 완료
# 188일차 자료 수집 완료
# 189일차 자료 수집 완료
# 190일차 자료 수집 완료
# 191일차 자료 수집 완료
# 192일차 자료 수집 완료
# 193일차 자료 수집 완료
# 194일차 자료 수집 완료
# 195일차 자료 수집 완료
# 196일차 자료 수집 완료
# 197일차 자료 수집 완료
# 198일차 자료 수집 완료
# 199일차 자료 수집 완료
# 200일차 자료 수집 완료
# 201일차 자료 수집 완료
# 202일차 자료 수집 완료
# 203일차 자료 수집 완료
# 204일차 자료 수집 완료
# 205일차 자료 수집 완료
# 206일차 자료 수집 완료
# 207일차 자료 수집 완료
# 208일차 자료 수집 완료
# 209일차 자료 수집 완료
# 210일차 자료 수집 완료
# 211일차 자료 수집 완료
# 212일차 자료 수집 완료
# 213일차 자료 수집 완료
# 214일차 자료 수집 완료
# 215일차 자료 수집 완료
# 216일차 자료 수집 완료
# 217일차 자료 수집 완료
# 218일차 자료 수집 완료
# 219일차 자료 수집 완료
# 220일차 자료 수집 완료
# 221일차 자료 수집 완료
# 222일차 자료 수집 완료
# 223일차 자료 수집 완료
# 224일차 자료 수집 완료
# 225일차 자료 수집 완료
# 226일차 자료 수집 완료
# 227일차 자료 수집 완료
# 228일차 자료 수집 완료
# 229일차 자료 수집 완료
# 230일차 자료 수집 완료
# 231일차 자료 수집 완료
# 232일차 자료 수집 완료
# 233일차 자료 수집 완료
# 234일차 자료 수집 완료
# 235일차 자료 수집 완료
# 236일차 자료 수집 완료
# 237일차 자료 수집 완료
# 238일차 자료 수집 완료
# 239일차 자료 수집 완료
# 240일차 자료 수집 완료
# 241일차 자료 수집 완료
# 242일차 자료 수집 완료
# 243일차 자료 수집 완료
# 244일차 자료 수집 완료
# 245일차 자료 수집 완료
# 246일차 자료 수집 완료
# 247일차 자료 수집 완료
# 248일차 자료 수집 완료
# 249일차 자료 수집 완료
# 250일차 자료 수집 완료
# 251일차 자료 수집 완료
# 252일차 자료 수집 완료
# 253일차 자료 수집 완료
# 254일차 자료 수집 완료
# 255일차 자료 수집 완료
# 256일차 자료 수집 완료
# 257일차 자료 수집 완료
# 258일차 자료 수집 완료
# 259일차 자료 수집 완료
# 260일차 자료 수집 완료
# 261일차 자료 수집 완료
# 262일차 자료 수집 완료
# 263일차 자료 수집 완료
# 264일차 자료 수집 완료
# 265일차 자료 수집 완료
# 266일차 자료 수집 완료
# 267일차 자료 수집 완료
# 268일차 자료 수집 완료
# 269일차 자료 수집 완료
# 270일차 자료 수집 완료
# 271일차 자료 수집 완료
# 272일차 자료 수집 완료
# 273일차 자료 수집 완료
# 274일차 자료 수집 완료
# 275일차 자료 수집 완료
# 276일차 자료 수집 완료
# 277일차 자료 수집 완료
# 278일차 자료 수집 완료
# 279일차 자료 수집 완료
# 280일차 자료 수집 완료
# 281일차 자료 수집 완료
# 282일차 자료 수집 완료
# 283일차 자료 수집 완료
# 284일차 자료 수집 완료
# 285일차 자료 수집 완료
# 286일차 자료 수집 완료
# 287일차 자료 수집 완료
# 288일차 자료 수집 완료
# 289일차 자료 수집 완료
# 290일차 자료 수집 완료
# 291일차 자료 수집 완료
# 292일차 자료 수집 완료
# 293일차 자료 수집 완료
# 294일차 자료 수집 완료
# 295일차 자료 수집 완료
# 296일차 자료 수집 완료
# 297일차 자료 수집 완료
# 298일차 자료 수집 완료
# 299일차 자료 수집 완료
# 300일차 자료 수집 완료
# 301일차 자료 수집 완료
# 302일차 자료 수집 완료
# 303일차 자료 수집 완료
# 304일차 자료 수집 완료
# 305일차 자료 수집 완료
# 306일차 자료 수집 완료
# 307일차 자료 수집 완료
# 308일차 자료 수집 완료
# 309일차 자료 수집 완료
# 310일차 자료 수집 완료
# 311일차 자료 수집 완료
# 312일차 자료 수집 완료
# 313일차 자료 수집 완료
# 314일차 자료 수집 완료
# 315일차 자료 수집 완료
# 316일차 자료 수집 완료
# 317일차 자료 수집 완료
# 318일차 자료 수집 완료
# 319일차 자료 수집 완료
# 320일차 자료 수집 완료
# 321일차 자료 수집 완료
# 322일차 자료 수집 완료
# 323일차 자료 수집 완료
# 324일차 자료 수집 완료
# 325일차 자료 수집 완료
# 326일차 자료 수집 완료
# 327일차 자료 수집 완료
# 328일차 자료 수집 완료
# 329일차 자료 수집 완료
# 330일차 자료 수집 완료
# 331일차 자료 수집 완료
# 332일차 자료 수집 완료
# 333일차 자료 수집 완료
# 334일차 자료 수집 완료
# 335일차 자료 수집 완료
# 336일차 자료 수집 완료
# 337일차 자료 수집 완료
# 338일차 자료 수집 완료
# 339일차 자료 수집 완료
# 340일차 자료 수집 완료
# 341일차 자료 수집 완료
# 342일차 자료 수집 완료
# 343일차 자료 수집 완료
# 344일차 자료 수집 완료
# 345일차 자료 수집 완료
# 346일차 자료 수집 완료
# 347일차 자료 수집 완료
# 348일차 자료 수집 완료
# 349일차 자료 수집 완료
# 350일차 자료 수집 완료
# 351일차 자료 수집 완료
# 352일차 자료 수집 완료
# 353일차 자료 수집 완료
# 354일차 자료 수집 완료
# 355일차 자료 수집 완료
# 356일차 자료 수집 완료
# 357일차 자료 수집 완료
# 358일차 자료 수집 완료
# 359일차 자료 수집 완료
# 360일차 자료 수집 완료
# 361일차 자료 수집 완료
# 362일차 자료 수집 완료
# 363일차 자료 수집 완료
# 364일차 자료 수집 완료
#    rnum rank rankInten rankOldAndNew   movieCd  \
# 0     1    1         0           OLD  20204117
# 1     2    2         0           OLD  20217845
# 2     3    3         0           OLD  20218391
# 3     4    4         0           OLD  20191951
# 4     5    5         0           OLD  20218875
# ..  ...  ...       ...           ...       ...
# 5     6    6         1           OLD  20209654
# 6     7    7        -1           OLD  20208446
# 7     8    8         0           OLD  20226107
# 8     9    9         0           OLD  20225237
# 9    10   10         0           OLD  20211792
#
#                             movieNm      openDt    salesAmt salesShare  \
# 0                              모가디슈  2021-07-28  2000829380       56.5
# 1                       더 수어사이드 스쿼드  2021-08-04   676797240       19.1
# 2                          보스 베이비 2  2021-07-21   284206020        8.0
# 3                            블랙 위도우  2021-07-07   194489780        5.5
# 4                 극장판 도라에몽: 진구의 신공룡  2021-08-05    88917620        2.5
# ..                              ...         ...         ...        ...
# 5                            헤어질 결심  2022-06-29   169174033        1.7
# 6                           외계+인 1부  2022-07-20   123965118        1.3
# 7   극장판 도라에몽: 진구의 우주소전쟁 리틀스타워즈 2021  2022-08-03    77727199        0.8
# 8                   명탐정 코난: 할로윈의 신부  2022-07-13    44635198        0.5
# 9                                헌트  2022-08-10    29793598        0.3
#
#     salesInten salesChange     salesAcc audiCnt audiInten audiChange  audiAcc  \
# 0     38859180           2  16579074530  196672      4041        2.1  1712375
# 1   -127499190       -15.9   2942253950   63095    -12197      -16.2   281377
# 2      1506480         0.5   7511398580   30046       108        0.4   836805
# 3    -28197330       -12.7  29457331370   18740     -2673      -12.5  2908679
# 4     -4415810        -4.7    337195080    9837      -612       -5.9    38669
# ..         ...         ...          ...     ...       ...        ...      ...
# 5    -32677140       -16.2  18385204948   15203     -2798      -15.5  1775050
# 6    -98324419       -44.2  15629862451   11690     -7177        -38  1496935
# 7      2170399         2.9    346253298    7903       248        3.2    36417
# 8       623298         1.4   4598589872    4122        13        0.3   442570
# 9     -2295602        -7.2    165546798    2377      -166       -6.5    16573
#
#    scrnCnt showCnt      date
# 0     1639    6757  20210808
# 1     1033    3306  20210808
# 2      777    1654  20210808
# 3      540     924  20210808
# 4      502     781  20210808
# ..     ...     ...       ...
# 5      266     426  20220807
# 6      374     499  20220807
# 7      357     466  20220807
# 8       91     115  20220807
# 9       12      13  20220807
#
# [3650 rows x 19 columns]

# %%
# 스크린당 평균 관객이 제일 많았던 영화를 뽑아주세요.
# 관객 총합 / 스크린 총합 = 스크린당 관객이 나옵니다.
# 컬럼 타입이 object이므로, 집계함수를 쓸 수 있도록 int로 컬럼 전체 자료형을 바꿔줘야 합니다.
# 현재 수치데이터도 전부 문자로 간주되고 있기 때문에 int로 자료형을 바꿔서 계산해야함
merged_data['audiCnt'] = merged_data['audiCnt'].astype(int)
merged_data['scrnCnt'] = merged_data['scrnCnt'].astype(int)

# %%
audi_scrn_sum = merged_data.pivot_table(index='movieNm', 
                                        values=['audiCnt','scrnCnt'], 
                                        aggfunc='sum').sort_values(by='audiCnt', 
                                                                   ascending=False)

# %%
# 관객 총합 / 스크린 총합 = 스크린당 관객이 나옵니다
# 컬럼명은 audiPerScrn
audi_scrn_sum['audiPerScrn'] = audi_scrn_sum['audiCnt'] / audi_scrn_sum['scrnCnt']
audi_scrn_sum
# Out:
#                       audiCnt  scrnCnt  audiPerScrn
# movieNm
# 범죄도시 2               12686014    81645   155.380170
# 스파이더맨: 노 웨이 홈         7541536    90668    83.177483
# 탑건: 매버릭               7448590    57863   128.728030
# 닥터 스트레인지: 대혼돈의 멀티버스   5880700    48993   120.031433
# 한산: 용의 출현             4597826    22656   202.940766
# ...                       ...      ...          ...
# 지지                        334        1   334.000000
# 포 언투 어스                   300        1   300.000000
# 맛있는 여동생                   259       20    12.950000
# 아이 스틸 빌리브                 217        2   108.500000
# 미싱타는 여자들                  201        1   201.000000
#
# [303 rows x 3 columns]

# %%
# 스크린당 관객수로 정렬해 가장 효율이 좋았던 영화들을 뽑아주세요.
# 집계대상의 스크린 개수는 최소 100개로 하겠습니다.
audi_scrn_sum[audi_scrn_sum['scrnCnt']>= 100].sort_values(by='audiPerScrn', ascending=False).head(20)
# Out:
#                                  audiCnt  scrnCnt  audiPerScrn
# movieNm
# 한산: 용의 출현                        4597826    22656   202.940766
# 비상선언                             1397962     8489   164.679232
# 범죄도시 2                          12686014    81645   155.380170
# 탑건: 매버릭                          7448590    57863   128.728030
# 닥터 스트레인지: 대혼돈의 멀티버스              5880700    48993   120.031433
# 쥬라기 월드: 도미니언                     2832531    24893   113.788254
# 마녀(魔女) Part2. The Other One      2795796    27322   102.327648
# 토르: 러브 앤 썬더                      2711863    26516   102.272703
# 미니언즈2                            1971475    19463   101.293480
# 스파이더맨: 노 웨이 홈                    7541536    90668    83.177483
# 너의 이름은.                            45672      552    82.739130
# 뜨거운 피: 디 오리지널                      12745      158    80.664557
# 외계+인 1부                          1493203    19211    77.726459
# 극장판 포켓몬스터DP: 기라티나와 하늘의 꽃다발 쉐이미    575641     7926    72.626924
# 비욘드라이브 더 무비 : 엔시티 레조넌스             15966      224    71.276786
# 헤어질 결심                           1774163    27562    64.369893
# 브로커                              1252060    19738    63.433985
# 이터널스                             3045398    48675    62.565958
# 싱크홀                              2178353    35019    62.204889
# 그대가 조국                            324303     5728    56.617144

# %%
# 스크린 개수가 50개 이상인 영화중 스크린당 관객수가 평균이상인 영화만 나열해주세요
audi_scrn_sum[audi_scrn_sum['scrnCnt'] >= 50]['audiPerScrn'].mean()
# Out:
# 26.8286906923845

# %%
final_data = audi_scrn_sum[(audi_scrn_sum['scrnCnt'] >= 50) & (audi_scrn_sum['audiPerScrn']>=26.8)].head(50)

# %%
# csv로 export하기
final_data.to_csv('평균이상영화.csv', encoding="utf-8")

# %%
# excel로 export하기
final_data.to_excel('평균이상영화.xlsx', encoding="utf-8")

# %% [markdown]
# # 가져온 데이터 mysql에 연동하기
#
# - import pymysql
# - 을 활용해서 연동할 수 있습니다.
#
# - 임포트가 되지 않는다면 다시 설치를 해야합니다.
# 1. Anaconda Navigator에서 좌측 탭의 enviroments를 누릅니다.
# 2. Open terminal을 이용해 cmd창같은 창을 켭니다.(터미널창이라고 부릅니다.)
# 3. pip install pymysql 을 입력하고 실행합니다.
#
# ### 오라클 연동
#
# 위와 같은데 3번에서
# - pip install cx_Oracle
# - 을 대신 입력해서 설치하면 됩니다.

# %%
# pymysql 실행을 해야 DB와 연결할 수 있습니다.
import pymysql

# %%
# MySQL 연결에 필요한 정보를 입력합니다.
con = pymysql.connect(host='localhost', user='root', password='mysql', db='pyprac2', charset='utf8',
                     cursorclass=pymysql.cursors.DictCursor) # 컬럼명까지 받아올지 여부

# %%
# SQL구문을 받아주는 cursor 객체를 사용합니다.
cur = con.cursor()

# %%
# SQL구문은 문자로 cur.execute()를 실행해서 수행시킵니다.
cur.execute("SELECT * FROM test_tbl2")
# Out:
# 8

# %%
# execute가 실행되면, cur가 데이터를 저장하고 있는데 이걸 파이선 형식으로 뺴야합니다.
mysql_data = cur.fetchall()

# %%
mysql_data
# Out:
# [{'tno': 1, 'tname': 'a'},
#  {'tno': 2, 'tname': 'b'},
#  {'tno': 3, 'tname': 'c'},
#  {'tno': 4, 'tname': 'd'},
#  {'tno': 5, 'tname': 'e'},
#  {'tno': 6, 'tname': 'f'},
#  {'tno': 7, 'tname': 'g'},
#  {'tno': 8, 'tname': 'g'}]

# %%
# 데이터프레임 형태로 변환
pd.DataFrame(mysql_data)
# Out:
#    tno tname
# 0    1     a
# 1    2     b
# 2    3     c
# 3    4     d
# 4    5     e
# 5    6     f
# 6    7     g
# 7    8     g

# %%
# 여러분들이 data 'g'를 넣어보세요.
cur.execute("INSERT INTO test_tbl2 VALUES (null, 'g')")
# Out:
# 1

# %%
# 커서가 아닌 커넥션에 commit을 주는것에 주의해주세요.
con.commit()

# %%
# 다시 select구문을 날려서 DB에 추가되었는지 확인까지해주세요
cur.execute("SELECT * FROM test_tbl2")
# Out:
# 9

# %%
result_data = cur.fetchall()

# %%
pd.DataFrame(result_data)
# Out:
#    tno tname
# 0    1     a
# 1    2     b
# 2    3     c
# 3    4     d
# 4    5     e
# 5    6     f
# 6    7     g
# 7    8     g
# 8    9     g

# %%
merged_data.head()
# Out:
#   rnum rank rankInten rankOldAndNew   movieCd            movieNm      openDt  \
# 0    1    1         0           OLD  20204117               모가디슈  2021-07-28
# 1    2    2         0           OLD  20217845        더 수어사이드 스쿼드  2021-08-04
# 2    3    3         0           OLD  20218391           보스 베이비 2  2021-07-21
# 3    4    4         0           OLD  20191951             블랙 위도우  2021-07-07
# 4    5    5         0           OLD  20218875  극장판 도라에몽: 진구의 신공룡  2021-08-05
#
#      salesAmt salesShare  salesInten salesChange     salesAcc  audiCnt  \
# 0  2000829380       56.5    38859180           2  16579074530   196672
# 1   676797240       19.1  -127499190       -15.9   2942253950    63095
# 2   284206020        8.0     1506480         0.5   7511398580    30046
# 3   194489780        5.5   -28197330       -12.7  29457331370    18740
# 4    88917620        2.5    -4415810        -4.7    337195080     9837
#
#   audiInten audiChange  audiAcc  scrnCnt showCnt      date
# 0      4041        2.1  1712375     1639    6757  20210808
# 1    -12197      -16.2   281377     1033    3306  20210808
# 2       108        0.4   836805      777    1654  20210808
# 3     -2673      -12.5  2908679      540     924  20210808
# 4      -612       -5.9    38669      502     781  20210808

# %%
# 로우개수
len(merged_data) # 3650번 반복해야 DB에 insert가 된다는 걸 알 수 있임
# iloc[], .loc[]를 이용하면 특정 로우 자료를 조회할 수 있고 거기서 ['컬럼명']을 집어넣으면
# 특정 로우의 값을 집어넣을 수 있어요.
merged_data.iloc[4]['movieNm']


# movie_tbl 데이터를 다 삭제하는 쿼리문을 날려주세요
#cur.execute("DELETE FROM movie_tbl")
#con.commit()
# Out:
# '극장판 도라에몽: 진구의 신공룡'

# %%
# 로우개수
len(merged_data) # 3650번 반복해야 DB에 insert가 된다는걸 알 수 있음.
# iloc[], .loc[] 를 이ㅛㅇ하면 특정 로우자료를 조회할 수 있고, 거기서 ['컬럼명']을 집어넣으면
# 특정 로우의 특정 컬럼값을 조회할 수 있습니다.
merged_data.iloc[4]['movieNm']
# Out:
# '극장판 도라에몽: 진구의 신공룡'

# %%
# 과제. MySQL이나 Oracle SQL에 현재 보고있는 db_insert데이터를
# 테이블 생성 및 반복문을 이용해서 다 DB에 넣어주시면 됩니다.
# 반복문을 이용해서 merged_data의 모든 데이터를 MySQL에 집어넣어주세요.
# 집어넣을 컬럼은 rnum, movieNm, openDt, audiCnt, showCnt, date

# %%
cur.execute("INSERT INTO movie_tbl (movieNm, openDt, audiCnt, showCnt, dataDate) VALUES ('%s', '%s', %s, %s, '%s')" % ("테스트", '2022-08-10', 300, 1, '20220810'))
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Input In [212], in <cell line: 1>()
# ----> 1 cur.execute("INSERT INTO movie_tbl (movieNm, openDt, audiCnt, showCnt, dataDate) VALUES ('%s', '%s', %s, %s, '%s')" % ("테스트", '2022-08-10', 300, 1, '20220810'))
#
# File C:\anaconda\lib\site-packages\pymysql\cursors.py:148, in Cursor.execute(self, query, args)
#     144     pass
#     146 query = self.mogrify(query, args)
# --> 148 result = self._query(query)
#     149 self._executed = query
#     150 return result
#
# File C:\anaconda\lib\site-packages\pymysql\cursors.py:310, in Cursor._query(self, q)
#     308 self._last_executed = q
#     309 self._clear_result()
# --> 310 conn.query(q)
#     311 self._do_get_result()
#     312 return self.rowcount
#
# File C:\anaconda\lib\site-packages\pymysql\connections.py:548, in Connection.query(self, sql, unbuffered)
#     546     sql = sql.encode(self.encoding, "surrogateescape")
#     547 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 548 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     549 return self._affected_rows
#
# File C:\anaconda\lib\site-packages\pymysql\connections.py:775, in Connection._read_query_result(self, unbuffered)
#     773 else:
#     774     result = MySQLResult(self)
# --> 775     result.read()
#     776 self._result = result
#     777 if result.server_status is not None:
#
# File C:\anaconda\lib\site-packages\pymysql\connections.py:1156, in MySQLResult.read(self)
#    1154 def read(self):
#    1155     try:
# -> 1156         first_packet = self.connection._read_packet()
#    1158         if first_packet.is_ok_packet():
#    1159             self._read_ok_packet(first_packet)
#
# File C:\anaconda\lib\site-packages\pymysql\connections.py:725, in Connection._read_packet(self, packet_type)
#     723     if self._result is not None and self._result.unbuffered_active is True:
#     724         self._result.unbuffered_active = False
# --> 725     packet.raise_for_error()
#     726 return packet
#
# File C:\anaconda\lib\site-packages\pymysql\protocol.py:221, in MysqlPacket.raise_for_error(self)
#     219 if DEBUG:
#     220     print("errno =", errno)
# --> 221 err.raise_mysql_exception(self._data)
#
# File C:\anaconda\lib\site-packages\pymysql\err.py:143, in raise_mysql_exception(data)
#     141 if errorclass is None:
#     142     errorclass = InternalError if errno < 1000 else OperationalError
# --> 143 raise errorclass(errno, errval)
#
# ProgrammingError: (1146, "Table 'pyprac2.movie_tbl' doesn't exist")

# %%
con.commit()

# %%
# merged_data변수 내부의 영화 제목만 한 줄 한 줄 콘솔에 찍어보세요
# len() 을 이용해 데이터프레임의 로우 개수를 구할 수 있습니다.
range(len(merged_data))
# 위 range를 이용해 iloc[번호] 로 로우를 순서대로 조회가능합니다.
for i in range(len(merged_data)):
    selected_data = merged_data.iloc[i]
    print(selected_data['movieNm'])
    #나머지(개봉일, 관객수, 상영수, 데이터날짜)
    print(selected_data['openDt'])
    print(selected_data['audiCnt'])
    print(selected_data['showCnt'])
    print(selected_data['date'])
    print("-------------------------")
    
    cur.execute("INSERT INTO movie_tbl (movieNm, openDt, a)")

# %%
# 날짜형으로 바꾸고 싶은 컬럼을 pd.to_datetime()에 넣어주면 변환됩니다.
merged_data['openDt'] = merged_data['openDt'].astype('datetime64[ns]')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File C:\anaconda\lib\site-packages\pandas\core\arrays\datetimes.py:2211, in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2210 try:
# -> 2211     values, tz_parsed = conversion.datetime_to_datetime64(data.ravel("K"))
#    2212     # If tzaware, these values represent unix timestamps, so we
#    2213     #  return them as i8 to distinguish from wall times
#
# File C:\anaconda\lib\site-packages\pandas\_libs\tslibs\conversion.pyx:360, in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ParserError                               Traceback (most recent call last)
# Input In [213], in <cell line: 2>()
#       1 # 날짜형으로 바꾸고 싶은 컬럼을 pd.to_datetime()에 넣어주면 변환됩니다.
# ----> 2 merged_data['openDt'] = merged_data['openDt'].astype('datetime64[ns]')
#
# File C:\anaconda\lib\site-packages\pandas\core\generic.py:5912, in NDFrame.astype(self, dtype, copy, errors)
#    5905     results = [
#    5906         self.iloc[:, i].astype(dtype, copy=copy)
#    5907         for i in range(len(self.columns))
#    5908     ]
#    5910 else:
#    5911     # else, only a single dtype is given
# -> 5912     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913     return self._constructor(new_data).__finalize__(self, method="astype")
#    5915 # GH 33113: handle empty frame or series
#
# File C:\anaconda\lib\site-packages\pandas\core\internals\managers.py:419, in BaseBlockManager.astype(self, dtype, copy, errors)
#     418 def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 419     return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#
# File C:\anaconda\lib\site-packages\pandas\core\internals\managers.py:304, in BaseBlockManager.apply(self, f, align_keys, ignore_failures, **kwargs)
#     302         applied = b.apply(f, **kwargs)
#     303     else:
# --> 304         applied = getattr(b, f)(**kwargs)
#     305 except (TypeError, NotImplementedError):
#     306     if not ignore_failures:
#
# File C:\anaconda\lib\site-packages\pandas\core\internals\blocks.py:580, in Block.astype(self, dtype, copy, errors)
#     562 """
#     563 Coerce to the new dtype.
#     564
#    (...)
#     576 Block
#     577 """
#     578 values = self.values
# --> 580 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     582 new_values = maybe_coerce_values(new_values)
#     583 newb = self.make_block(new_values)
#
# File C:\anaconda\lib\site-packages\pandas\core\dtypes\cast.py:1292, in astype_array_safe(values, dtype, copy, errors)
#    1289     dtype = dtype.numpy_dtype
#    1291 try:
# -> 1292     new_values = astype_array(values, dtype, copy=copy)
#    1293 except (ValueError, TypeError):
#    1294     # e.g. astype_nansafe can fail on object-dtype of strings
#    1295     #  trying to convert to float
#    1296     if errors == "ignore":
#
# File C:\anaconda\lib\site-packages\pandas\core\dtypes\cast.py:1237, in astype_array(values, dtype, copy)
#    1234     values = values.astype(dtype, copy=copy)
#    1236 else:
# -> 1237     values = astype_nansafe(values, dtype, copy=copy)
#    1239 # in pandas we don't store numpy str dtypes, so convert to object
#    1240 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File C:\anaconda\lib\site-packages\pandas\core\dtypes\cast.py:1163, in astype_nansafe(arr, dtype, copy, skipna)
#    1159 elif is_datetime64_dtype(dtype):
#    1160     from pandas import to_datetime
#    1162     return astype_nansafe(
# -> 1163         to_datetime(arr).values,
#    1164         dtype,
#    1165         copy=copy,
#    1166     )
#    1167 elif is_timedelta64_dtype(dtype):
#    1168     from pandas import to_timedelta
#
# File C:\anaconda\lib\site-packages\pandas\core\tools\datetimes.py:1063, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1061 elif is_list_like(arg):
#    1062     try:
# -> 1063         cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1064     except OutOfBoundsDatetime:
#    1065         # caching attempts to create a DatetimeIndex, which may raise
#    1066         # an OOB. If that's the desired behavior, then just reraise...
#    1067         if errors == "raise":
#
# File C:\anaconda\lib\site-packages\pandas\core\tools\datetimes.py:197, in _maybe_cache(arg, format, cache, convert_listlike)
#     195 unique_dates = unique(arg)
#     196 if len(unique_dates) < len(arg):
# --> 197     cache_dates = convert_listlike(unique_dates, format)
#     198     cache_array = Series(cache_dates, index=unique_dates)
#     199     # GH#39882 and GH#35888 in case of None and NaT we get duplicates
#
# File C:\anaconda\lib\site-packages\pandas\core\tools\datetimes.py:402, in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     400 assert format is None or infer_datetime_format
#     401 utc = tz == "utc"
# --> 402 result, tz_parsed = objects_to_datetime64ns(
#     403     arg,
#     404     dayfirst=dayfirst,
#     405     yearfirst=yearfirst,
#     406     utc=utc,
#     407     errors=errors,
#     408     require_iso8601=require_iso8601,
#     409     allow_object=True,
#     410 )
#     412 if tz_parsed is not None:
#     413     # We can take a shortcut since the datetime64 numpy array
#     414     # is in UTC
#     415     dta = DatetimeArray(result, dtype=tz_to_dtype(tz_parsed))
#
# File C:\anaconda\lib\site-packages\pandas\core\arrays\datetimes.py:2217, in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2215         return values.view("i8"), tz_parsed
#    2216     except (ValueError, TypeError):
# -> 2217         raise err
#    2219 if tz_parsed is not None:
#    2220     # We can take a shortcut since the datetime64 numpy array
#    2221     #  is in UTC
#    2222     # Return i8 values to denote unix timestamps
#    2223     return result.view("i8"), tz_parsed
#
# File C:\anaconda\lib\site-packages\pandas\core\arrays\datetimes.py:2199, in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2197 order: Literal["F", "C"] = "F" if flags.f_contiguous else "C"
#    2198 try:
# -> 2199     result, tz_parsed = tslib.array_to_datetime(
#    2200         data.ravel("K"),
#    2201         errors=errors,
#    2202         utc=utc,
#    2203         dayfirst=dayfirst,
#    2204         yearfirst=yearfirst,
#    2205         require_iso8601=require_iso8601,
#    2206         allow_mixed=allow_mixed,
#    2207     )
#    2208     result = result.reshape(data.shape, order=order)
#    2209 except ValueError as err:
#
# File C:\anaconda\lib\site-packages\pandas\_libs\tslib.pyx:381, in pandas._libs.tslib.array_to_datetime()
#
# File C:\anaconda\lib\site-packages\pandas\_libs\tslib.pyx:613, in pandas._libs.tslib.array_to_datetime()
#
# File C:\anaconda\lib\site-packages\pandas\_libs\tslib.pyx:751, in pandas._libs.tslib._array_to_datetime_object()
#
# File C:\anaconda\lib\site-packages\pandas\_libs\tslib.pyx:742, in pandas._libs.tslib._array_to_datetime_object()
#
# File C:\anaconda\lib\site-packages\pandas\_libs\tslibs\parsing.pyx:281, in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# File C:\anaconda\lib\site-packages\dateutil\parser\_parser.py:1368, in parse(timestr, parserinfo, **kwargs)
#    1366     return parser(parserinfo).parse(timestr, **kwargs)
#    1367 else:
# -> 1368     return DEFAULTPARSER.parse(timestr, **kwargs)
#
# File C:\anaconda\lib\site-packages\dateutil\parser\_parser.py:646, in parser.parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     643     raise ParserError("Unknown string format: %s", timestr)
#     645 if len(res) == 0:
# --> 646     raise ParserError("String does not contain a date: %s", timestr)
#     648 try:
#     649     ret = self._build_naive(res, default)
#
# ParserError: String does not contain a date:

# %%
# 날짜가 안 들어가는 이유는, 개봉날짜가 빈 칸으로(날짜형식이 아닌) 집계되는 부분이 있어서입니다.
# 따라서 결측치나 이상값을 집계가능한 값으로 돌려놓고(1900-01-01) 다시 insert를 하면 됩니다.
# 반복문으로 인덱스번호, 날짜 형식으로 출력하도록 해서 몇 번 인덱스가 결측치인지 파악해보겠습니다.
for i in range(len(merged_data)):
    print(i, merged_data['openDt'].iloc[i])

# %%
# 조건색인으로 날짜가 빈 요소만 체크해서 1900-01-01로 집어넣어보세요
merged_data['openDt'][merged_data['openDt'] == ' '] = '1900-01-01'

# %%
merged_data['openDt'].contain("'")

# %%
# 인덱스가 365일치를 겹쳐서 받아오기 때문에 중복인덱스가 생기므로, 초기화
merged_data = merged_data.reset_index()

# %%
merged_data

# %%
# 특정 요소에 특정한 문자가 포함되었는지는
# .str.conatins("조회문자") 형식으로 확인 가능합니다.
merged_data['movieNm'][merged_data['movieNm'].str.contains("'")]

# %%
# 위의 방식으로 우리가 수정해야할 movieNm의 인덱스번호만 얻어올 수 있음
target_rnum = merged_data[['rnum','movieNm']][merged_data['movieNm'].str.contains("'")].index

# %%
target_rnum

# %%
for i in target_rnum:
   merged_data.iloc[i]['movieNm'] = merged_data['movieNm'][merged_data['movieNm'].str.contains("'")].str.replace("'"," ")

# %%
merged_data.iloc[target_rnum]['movieNm']

# %%
# apply()를 이용한 전처리
# .apply()는 데이터프레임에 적용해서, 사용자가 전처리 형식을 직접 지정해 적용할 수 있도록 도와줍니다.
# 함수를 이용해 처리합니다.
# 지금같은경우, '가 포함된 문자열을 '를 제거한 형태로 바꾸려 하므로 해당 로직을 함수로 만들어 저장하고
# 그 다음 적용하고 싶은 컬럼에 .apply()를 걸어 적용하면됩니다.

# %%
# 요소를 읽어서, '가 포함된 경우 삭제한 다음 리턴하는 함수 작성
def deletion_char(target):
    return target.replace("'", "")

# %%
# 함수가 만들어졌으면, 수정해줄 컬럼을 지정하고, 거기에 apply()를 쓴 다음 함수명을 내부에 파라미터로 줍니다.
merged_data['movieNm'] = merged_data['movieNm'].apply(deletion_char)

# %%
merged_data.iloc[target_rnum]

# %%
# apply로 또 해결합니다
def set_date(target):
    if(target == ' '):
        return '1900-01-01'
    return target

# %%
# 조건색인으로 2021년 10월 23일 데이터를 다시 봅니다.
merged_data['openDt'] = merged_data['openDt'].apply(set_date)

# %%
merged_data['openDt']

# %%
#위의 반복문 코드를 응용해 전체 데이터를 다 DB에 넣고 확인해주세요.
for i in range(len(merged_data)):
    selected_row = merged_data.iloc[i]
    cur.execute("INSERT INTO movie_tbl (movieNm, openDt, audiCnt, showCnt, dataDate) VALUES ('%s', '%s', %s, %s, '%s')" % (selected_row['movieNm'], 
                                                                                                                           selected_row['openDt'], 
                                                                                                                           selected_row['audiCnt'], 
                                                                                                                           selected_row['showCnt'], 
                                                                                                                           selected_row['date']))
con.commit()

# %%
con.commit()

# %%
#SELECT구문 날려서 DataFrame으로 다시받아오기
cur.execute("SELECT * FROM movie_tbl")
movie_tbl = cur.fetchall()
pd.DataFrame(movie_tbl)

# %% [markdown]
# # 위 로직을 똑같이 오라클에서도 활용할 수 있습니다. 직접 해 보세요.

# %%
import cx_Oracle

# %%
# Oracle 연동
# 11버전은 localhost:1521/XE
# 18버전은 localhost:1521/XEPDB1
con_oracle = cx_Oracle.connect("mytest", "mytest", "localhost:1521/XEPDB1")

# %%
# 커서 얻어온 뒤부터는 mysql과 동일하게 cur.fetchall() 등을 이용해 처리할 수 있음.
cur_oracle = con_oracle.cursor()

# 날짜형으로 바꾸고 싶은 컬럼을 pd.to_datetime()에 넣어서 변환
merged_data['openDt'] = merged_data['openDt'].astype('datetime64[ns]')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File C:\anaconda\lib\site-packages\pandas\core\arrays\datetimes.py:2211, in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2210 try:
# -> 2211     values, tz_parsed = conversion.datetime_to_datetime64(data.ravel("K"))
#    2212     # If tzaware, these values represent unix timestamps, so we
#    2213     #  return them as i8 to distinguish from wall times
#
# File C:\anaconda\lib\site-packages\pandas\_libs\tslibs\conversion.pyx:360, in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ParserError                               Traceback (most recent call last)
# Input In [221], in <cell line: 5>()
#       2 cur_oracle = con_oracle.cursor()
#       4 # 날짜형으로 바꾸고 싶은 컬럼을 pd.to_datetime()에 넣어서 변환
# ----> 5 merged_data['openDt'] = merged_data['openDt'].astype('datetime64[ns]')
#
# File C:\anaconda\lib\site-packages\pandas\core\generic.py:5912, in NDFrame.astype(self, dtype, copy, errors)
#    5905     results = [
#    5906         self.iloc[:, i].astype(dtype, copy=copy)
#    5907         for i in range(len(self.columns))
#    5908     ]
#    5910 else:
#    5911     # else, only a single dtype is given
# -> 5912     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913     return self._constructor(new_data).__finalize__(self, method="astype")
#    5915 # GH 33113: handle empty frame or series
#
# File C:\anaconda\lib\site-packages\pandas\core\internals\managers.py:419, in BaseBlockManager.astype(self, dtype, copy, errors)
#     418 def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 419     return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#
# File C:\anaconda\lib\site-packages\pandas\core\internals\managers.py:304, in BaseBlockManager.apply(self, f, align_keys, ignore_failures, **kwargs)
#     302         applied = b.apply(f, **kwargs)
#     303     else:
# --> 304         applied = getattr(b, f)(**kwargs)
#     305 except (TypeError, NotImplementedError):
#     306     if not ignore_failures:
#
# File C:\anaconda\lib\site-packages\pandas\core\internals\blocks.py:580, in Block.astype(self, dtype, copy, errors)
#     562 """
#     563 Coerce to the new dtype.
#     564
#    (...)
#     576 Block
#     577 """
#     578 values = self.values
# --> 580 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     582 new_values = maybe_coerce_values(new_values)
#     583 newb = self.make_block(new_values)
#
# File C:\anaconda\lib\site-packages\pandas\core\dtypes\cast.py:1292, in astype_array_safe(values, dtype, copy, errors)
#    1289     dtype = dtype.numpy_dtype
#    1291 try:
# -> 1292     new_values = astype_array(values, dtype, copy=copy)
#    1293 except (ValueError, TypeError):
#    1294     # e.g. astype_nansafe can fail on object-dtype of strings
#    1295     #  trying to convert to float
#    1296     if errors == "ignore":
#
# File C:\anaconda\lib\site-packages\pandas\core\dtypes\cast.py:1237, in astype_array(values, dtype, copy)
#    1234     values = values.astype(dtype, copy=copy)
#    1236 else:
# -> 1237     values = astype_nansafe(values, dtype, copy=copy)
#    1239 # in pandas we don't store numpy str dtypes, so convert to object
#    1240 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File C:\anaconda\lib\site-packages\pandas\core\dtypes\cast.py:1163, in astype_nansafe(arr, dtype, copy, skipna)
#    1159 elif is_datetime64_dtype(dtype):
#    1160     from pandas import to_datetime
#    1162     return astype_nansafe(
# -> 1163         to_datetime(arr).values,
#    1164         dtype,
#    1165         copy=copy,
#    1166     )
#    1167 elif is_timedelta64_dtype(dtype):
#    1168     from pandas import to_timedelta
#
# File C:\anaconda\lib\site-packages\pandas\core\tools\datetimes.py:1063, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1061 elif is_list_like(arg):
#    1062     try:
# -> 1063         cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1064     except OutOfBoundsDatetime:
#    1065         # caching attempts to create a DatetimeIndex, which may raise
#    1066         # an OOB. If that's the desired behavior, then just reraise...
#    1067         if errors == "raise":
#
# File C:\anaconda\lib\site-packages\pandas\core\tools\datetimes.py:197, in _maybe_cache(arg, format, cache, convert_listlike)
#     195 unique_dates = unique(arg)
#     196 if len(unique_dates) < len(arg):
# --> 197     cache_dates = convert_listlike(unique_dates, format)
#     198     cache_array = Series(cache_dates, index=unique_dates)
#     199     # GH#39882 and GH#35888 in case of None and NaT we get duplicates
#
# File C:\anaconda\lib\site-packages\pandas\core\tools\datetimes.py:402, in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     400 assert format is None or infer_datetime_format
#     401 utc = tz == "utc"
# --> 402 result, tz_parsed = objects_to_datetime64ns(
#     403     arg,
#     404     dayfirst=dayfirst,
#     405     yearfirst=yearfirst,
#     406     utc=utc,
#     407     errors=errors,
#     408     require_iso8601=require_iso8601,
#     409     allow_object=True,
#     410 )
#     412 if tz_parsed is not None:
#     413     # We can take a shortcut since the datetime64 numpy array
#     414     # is in UTC
#     415     dta = DatetimeArray(result, dtype=tz_to_dtype(tz_parsed))
#
# File C:\anaconda\lib\site-packages\pandas\core\arrays\datetimes.py:2217, in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2215         return values.view("i8"), tz_parsed
#    2216     except (ValueError, TypeError):
# -> 2217         raise err
#    2219 if tz_parsed is not None:
#    2220     # We can take a shortcut since the datetime64 numpy array
#    2221     #  is in UTC
#    2222     # Return i8 values to denote unix timestamps
#    2223     return result.view("i8"), tz_parsed
#
# File C:\anaconda\lib\site-packages\pandas\core\arrays\datetimes.py:2199, in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2197 order: Literal["F", "C"] = "F" if flags.f_contiguous else "C"
#    2198 try:
# -> 2199     result, tz_parsed = tslib.array_to_datetime(
#    2200         data.ravel("K"),
#    2201         errors=errors,
#    2202         utc=utc,
#    2203         dayfirst=dayfirst,
#    2204         yearfirst=yearfirst,
#    2205         require_iso8601=require_iso8601,
#    2206         allow_mixed=allow_mixed,
#    2207     )
#    2208     result = result.reshape(data.shape, order=order)
#    2209 except ValueError as err:
#
# File C:\anaconda\lib\site-packages\pandas\_libs\tslib.pyx:381, in pandas._libs.tslib.array_to_datetime()
#
# File C:\anaconda\lib\site-packages\pandas\_libs\tslib.pyx:613, in pandas._libs.tslib.array_to_datetime()
#
# File C:\anaconda\lib\site-packages\pandas\_libs\tslib.pyx:751, in pandas._libs.tslib._array_to_datetime_object()
#
# File C:\anaconda\lib\site-packages\pandas\_libs\tslib.pyx:742, in pandas._libs.tslib._array_to_datetime_object()
#
# File C:\anaconda\lib\site-packages\pandas\_libs\tslibs\parsing.pyx:281, in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# File C:\anaconda\lib\site-packages\dateutil\parser\_parser.py:1368, in parse(timestr, parserinfo, **kwargs)
#    1366     return parser(parserinfo).parse(timestr, **kwargs)
#    1367 else:
# -> 1368     return DEFAULTPARSER.parse(timestr, **kwargs)
#
# File C:\anaconda\lib\site-packages\dateutil\parser\_parser.py:646, in parser.parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     643     raise ParserError("Unknown string format: %s", timestr)
#     645 if len(res) == 0:
# --> 646     raise ParserError("String does not contain a date: %s", timestr)
#     648 try:
#     649     ret = self._build_naive(res, default)
#
# ParserError: String does not contain a date:

# %%
# oracle을 켜서 테이블을 똑같이 만들어주시고, 위의 mysql로직에서 얻어온 merged_data를 역시
# oracle DB에도 적재해주시고 다시 꺼내서 DataFrame화를 시켜주시면 됩니다.
#위의 반복문 코드를 응용해 전체 데이터를 다 DB에 넣고 확인해주세요.
for i in range(len(merged_data)):
    selected_row = merged_data.iloc[i]
    cur_oracle.execute("INSERT INTO movie_tbl VALUES (movieNum.nextval, '%s', '%s', %s, %s, '%s')" % (selected_row['movieNm'], 
                                                                                                                           selected_row['openDt'], 
                                                                                                                           selected_row['audiCnt'], 
                                                                                                                           selected_row['showCnt'], 
                                                                                                                           selected_row['date']))
con_oracle.commit()

# %%
#SELECT구문 날려서 DataFrame으로 다시받아오기
cur_oracle.execute("SELECT * FROM movie_tbl")
movie_tbl = cur_oracle.fetchall()
movie_db_data = pd.DataFrame(movie_tbl)

# %%
movie_db_data.columns = ['rnum', 'movieNm', 'openDt', 'audiCnt', 'showcnt', 'dataDate']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [220], in <cell line: 1>()
# ----> 1 movie_db_data.columns = ['rnum', 'movieNm', 'openDt', 'audiCnt', 'showcnt', 'dataDate']
#
# File C:\anaconda\lib\site-packages\pandas\core\generic.py:5588, in NDFrame.__setattr__(self, name, value)
#    5586 try:
#    5587     object.__getattribute__(self, name)
# -> 5588     return object.__setattr__(self, name, value)
#    5589 except AttributeError:
#    5590     pass
#
# File C:\anaconda\lib\site-packages\pandas\_libs\properties.pyx:70, in pandas._libs.properties.AxisProperty.__set__()
#
# File C:\anaconda\lib\site-packages\pandas\core\generic.py:769, in NDFrame._set_axis(self, axis, labels)
#     767 def _set_axis(self, axis: int, labels: Index) -> None:
#     768     labels = ensure_index(labels)
# --> 769     self._mgr.set_axis(axis, labels)
#     770     self._clear_item_cache()
#
# File C:\anaconda\lib\site-packages\pandas\core\internals\managers.py:214, in BaseBlockManager.set_axis(self, axis, new_labels)
#     212 def set_axis(self, axis: int, new_labels: Index) -> None:
#     213     # Caller is responsible for ensuring we have an Index object.
# --> 214     self._validate_set_axis(axis, new_labels)
#     215     self.axes[axis] = new_labels
#
# File C:\anaconda\lib\site-packages\pandas\core\internals\base.py:69, in DataManager._validate_set_axis(self, axis, new_labels)
#      66     pass
#      68 elif new_len != old_len:
# ---> 69     raise ValueError(
#      70         f"Length mismatch: Expected axis has {old_len} elements, new "
#      71         f"values have {new_len} elements"
#      72     )
#
# ValueError: Length mismatch: Expected axis has 0 elements, new values have 6 elements

# %%
movie_db_data
